# %% [markdown]
# ## Lab 2- Tic Tac Toe
#
# ## Student Name: Michael Sheehey
# ## Student ID: 1001429239
#
# In this lab your will build a n x n Tic Tac Toe game. As you do the exercises, make sure your solutions work for any size Tic Tac Toe game.

# %% [markdown]
# *Exercise 1:* Write a function that creates an n by n matrix (of list of lists) which will represent the state of a Tie Tac Toe game. Let 0, 1, and 2 represent empty, "X", and "O", respectively.

# %%
# Index assignment for matrix
player_x = 1
player_o = 2
empty = 0

# Game board size 
size = 3
columns = ["A", "B", "C"]

def board_initializer(size):
# Use loop to build our matrix, matrix should use determined size 'n' to achieve n by n matrix
    board = list()
    for i in range(size): #builds list of size
        row = list() #sets row to a list
        for j in range(size): #set up to append value in our nested list (our values in row)
            row.append(empty)

        board.append(row) #append our newly created list to board and loop
    
    return board

# Lets try the hybrid compact way of creating this function
def board_initializer_compact(size):
    board = list()
    for i in range(size):
        board.append([empty]*size) #this approach loops through our created list of size and appends a list multiplied by size to our empty board list

    return board

# %%
board = board_initializer_compact(size)
board[0][1] = 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 board = board_initializer_compact(size)
#       2 board[0][1] = 1
#
# NameError: name 'size' is not defined

# %% [markdown]
# *Exercise 2:* Write a function that takes 2 integers `n` and `m` as input and draws a `n` by `m` game board. For example the following is a 3x3 board:
# ```
#    --- --- ---
#   |   |   |   |
#    --- --- ---
#   |   |   |   |
#    --- --- ---
#   |   |   |   |
#    --- --- ---
#    ```

# %%
#Our matrix is empty to start so all we need is to 
player_x_piece = "X" 
player_o_piece = "O"
empty_space = " " 

character = {player_x: player_x_piece, 
             player_o: player_o_piece,
             empty: empty_space}

def draw_board(board, size):
    columns = [chr(ord('A') + i) for i in range(size)]
    print("    " + "   ".join(columns)) # modded for col visual
    print('  ' + ' ---' * size)
    for i in range(size):
        row = ' | '.join([character[cell] for cell in board[i]])
        print(f'{i + 1} | {row} |') # modded for row visual
        if i < (size - 1): 
            print('  ' + ' ---' * size)
    print('  ' + ' ---' * size)

# %%
draw_board(board, size)
# Out:
#     A   B   C
#    --- --- ---
# 1 |   | X |   |
#    --- --- ---
# 2 |   |   |   |
#    --- --- ---
# 3 |   |   |   |
#    --- --- ---

# %% [markdown]
# *Exercise 3:* Modify exercise 2, so that it takes a matrix of the form from exercise 1 and draws a tic-tac-tie board with "X"s and "O"s.

# %%
# Above is the code, fused questions to make solution simpler.

# %%
board[0][2] = 2
draw_board(board, size)
# Out:
#     A   B   C
#    --- --- ---
# 1 |   | X | O |
#    --- --- ---
# 2 |   |   |   |
#    --- --- ---
# 3 |   |   |   |
#    --- --- ---

# %% [markdown]
# *Exercise 4:* Write a function that takes a `n` by `n` matrix representing a tic-tac-toe game, and returns -1, 0, 1, or 2 indicating the game is incomplete, the game is a draw, player 1 has won, or player 2 has one, respectively. Here are some example inputs you can use to test your code:

# %%
def check_winner(board, size):
    n = len(board)  # Get the size of the board
    is_draw = True  # Assume the game is a draw unless we find empty cells

    # Check rows and columns for a win
    for i in range(n):
        # Check row i
        if board[i][0] != 0 and all(board[i][j] == board[i][0] for j in range(n)):
            return board[i][0]
        # Check column i
        if board[0][i] != 0 and all(board[j][i] == board[0][i] for j in range(n)):
            return board[0][i]

    # Check main diagonal
    if board[0][0] != 0 and all(board[i][i] == board[0][0] for i in range(n)):
        return board[0][0]

    # Check anti-diagonal
    if board[0][n-1] != 0 and all(board[i][n-i-1] == board[0][n-1] for i in range(n)):
        return board[0][n-1]

    # Check if there are any empty cells (game incomplete)
    for row in board:
        if 0 in row:
            is_draw = False  # If there's an empty space, game isn't a draw

    # If no winner and no empty cells, it's a draw
    if is_draw:
        return 0
    else:
        return -1  # Game is incomplete
    

# Edit here so exercise 5 takes in row and col in format of "A1"
# first fix draw_board()
# next make func to convert for new place_player() input 
def input_convert(input, size):
    if len(input) != 2 or len(input) > 3: # user should only be able to enter str thats 2 chars long
        return None
    # make sure all input is excepted
    column = input[0].upper()
    row = input[1:]
# error handling
    if not column.isalpha() or ord(column) < ord('A') or ord(column) >= ord('A') + size:
        return None
    
    if not row.isdigit():
        return None
    
    row = int(row)
    if row < 1 or row > size:
        return None
    
    y = ord(column) - ord('A')
    x = row - 1

    return x, y

# next mod place_player() for new parameter

# %%
winner_is_2 = [[2, 2, 0],
	[2, 1, 0],
	[2, 1, 1]]

winner_is_1 = [[1, 2, 0],
	[2, 1, 0],
	[2, 1, 1]]

winner_is_also_1 = [[0, 1, 0],
	[2, 1, 0],
	[2, 1, 1]]

no_winner = [[1, 2, 0],
	[2, 1, 0],
	[2, 1, 2]]

also_no_winner = [[1, 2, 2],
	[2, 1, 1],
	[2, 1, 2]]

print(check_winner(winner_is_2))        # Output: 2 (Player 2 wins)
print(check_winner(winner_is_1))        # Output: 1 (Player 1 wins)
print(check_winner(winner_is_also_1))   # Output: 1 (Player 1 wins)
print(check_winner(no_winner))          # Output: -1 (Game incomplete)
print(check_winner(also_no_winner))
# Out:
# 2
# 1
# 1
# -1
# 0

# %% [markdown]
# *Exercise 5:* Write a function that takes a game board, player number, and `(x,y)` coordinates and places "X" or "O" in the correct location of the game board. Make sure that you only allow filling previously empty locations. Return `True` or `False` to indicate successful placement of "X" or "O".

# %%
# def place_player(board, player, x, y):
#     if 0 <= x < size and 0 <= y < size and board[x][y] == empty:
#         board[x][y] = player
#         return True
#     else:
#         return False
    
def place_player(board, player, input, size):
    coords = input_convert(input, size)
    if coords is None:
        print("PLEASE USE CORRECT FORMAT, EX: A1 OR C2")
        return False
    
    x, y = coords
    
    if 0 <= x < size and 0 <= y < size and board[x][y] == empty:
        board[x][y] = player
        return True
    else:
        if not (0 <= x < size and 0 <= y < size):
            print("Error: OUT OF BOUNDS. TRY AGAIN.")
        elif board[x][y] != empty:
            print("Error: COLLISION. SPACE OCCUPIED. TRY AGAIN.")
        return False

# %%
# Test your solution here
# place player x in the center of our board
# Fix test case to try again
# board[1][1] = empty
# place_player(board, player_x, 1, 1)
# draw_board(board)
# # now lets try to place an o in the same spot to check collision
# place_player(board, player_o, 1, 1)
# draw_board(board)
# # Good but there is no feedback for the user, add error message for player in place_player 
# # Try bounds case
# place_player(board, player_o, 1, 5)
# draw_board(board)
# Nioce
# retest of place_player()
place_player(board, player_x, 'A1', 3)
draw_board(board, size)
# check collision case
place_player(board, player_o, 'a1', 3)
draw_board(board, size)
# Out:
#     A   B   C
#    --- --- ---
# 1 | X | X | O |
#    --- --- ---
# 2 |   |   |   |
#    --- --- ---
# 3 |   |   |   |
#    --- --- ---
# Error: COLLISION. SPACE OCCUPIED. TRY AGAIN.
#     A   B   C
#    --- --- ---
# 1 | X | X | O |
#    --- --- ---
# 2 |   |   |   |
#    --- --- ---
# 3 |   |   |   |
#    --- --- ---

# %% [markdown]
# *Exercise 6:* Modify Exercise 4 to show column and row labels so that players can specify location using "A2" or "C1".

# %%
# Write you solution here
# Solution is given in exercise 4 to run proper order
# def input_convert(input):
#     if len(input) != 2: # user should only be able to enter str thats 2 chars long
#         return None
#     # make sure all input is excepted
#     column = input[0].upper()
#     row = input[1]
# # error handling
#     if column not in columns or not row.isdigit():
#         return None
    
#     x = int(row) - 1 # consider index
#     y = columns.index(column)

#     return x, y

# %%
# Test your solution here
# lets clear our board
board = board_initializer(3)
draw_board(board, size)
# test our cases
#1. place
place_player(board, player_x, 'A1', 3)
draw_board(board, size)
#2. bounds
place_player(board, player_x, 'a8', 3)
draw_board(board, size)
# Out:
#     A   B   C
#    --- --- ---
# 1 |   |   |   |
#    --- --- ---
# 2 |   |   |   |
#    --- --- ---
# 3 |   |   |   |
#    --- --- ---
#     A   B   C
#    --- --- ---
# 1 | X |   |   |
#    --- --- ---
# 2 |   |   |   |
#    --- --- ---
# 3 |   |   |   |
#    --- --- ---
# PLEASE USE CORRECT FORMAT, EX: A1 OR C2
#     A   B   C
#    --- --- ---
# 1 | X |   |   |
#    --- --- ---
# 2 |   |   |   |
#    --- --- ---
# 3 |   |   |   |
#    --- --- ---

# %%
# 3. check collision.
place_player(board, player_o, 'a1', 3)
draw_board(board, size)
# Out:
# Error: COLLISION. SPACE OCCUPIED. TRY AGAIN.
#     A   B   C
#    --- --- ---
# 1 | X |   |   |
#    --- --- ---
# 2 |   |   |   |
#    --- --- ---
# 3 |   |   |   |
#    --- --- ---

# %% [markdown]
# *Exercise 7:* Write a function that takes a board, player number, and location specified as in exercise 6 and then calls exercise 5 to correctly modify the board.

# %%
# Write you solution here
# Our place_player() was modified to do this along with our input_convert(). Code is below.
# 
# def input_convert(input):
#     if len(input) != 2: # user should only be able to enter str thats 2 chars long
#         return None
#     # make sure all input is excepted
#     column = input[0].upper()
#     row = input[1]
# # error handling
#     if column not in columns or not row.isdigit():
#         return None
    
#     x = int(row) - 1 # consider index
#     y = columns.index(column)

#     return x, y 

# def place_player(board, player, input):
#     coords = input_convert(input)
#     if coords is None:
#         print("PLEASE USE CORRECT FORMAT, EX: A1 OR C2")
#         return False
    
#     x, y = coords
    
#     if 0 <= x < size and 0 <= y < size and board[x][y] == empty:
#         board[x][y] = player
#         return True
#     else:
#         if not (0 <= x < size and 0 <= y < size):
#             print("Error: OUT OF BOUNDS. TRY AGAIN.")
#         elif board[x][y] != empty:
#             print("Error: COLLISION. SPACE OCCUPIED. TRY AGAIN.")
#         return False

# %%
# Test your solution here
place_player(board, player_o, 'B2', 3)
draw_board(board, size)
# Out:
#     A   B   C
#    --- --- ---
# 1 | X |   |   |
#    --- --- ---
# 2 |   | O |   |
#    --- --- ---
# 3 |   |   |   |
#    --- --- ---

# %% [markdown]
# *Exercise 8:* Write a function is called with a board and player number, takes input from the player using python's `input`, and modifies the board using your function from exercise 7. Note that you should keep asking for input until you have gotten a valid input that results in a valid move.

# %%
def player_move(board, player):
    # inform user of turn
    print(f"Player {player} ({character[player]}), enter your move.")
    while True:
        move = input(f"Player {player} ({character[player]}), enter your move.")

        if place_player(board, player, move, size):
            break
        else:
            print("Error: BAD MOVE. TRY AGAIN.")

# %%
# Test your solution here
# lets empty our board again
board = board_initializer(size)
draw_board(board, size)

#player 1
player_move(board, player_x)
draw_board(board, size)

#player 2
player_move(board, player_o)
draw_board(board, size)
# Out:
#     A   B   C
#    --- --- ---
# 1 |   |   |   |
#    --- --- ---
# 2 |   |   |   |
#    --- --- ---
# 3 |   |   |   |
#    --- --- ---
# Player 1 (X), enter your move.
# PLEASE USE CORRECT FORMAT, EX: A1 OR C2
# Error: BAD MOVE. TRY AGAIN.
#     A   B   C
#    --- --- ---
# 1 | X |   |   |
#    --- --- ---
# 2 |   |   |   |
#    --- --- ---
# 3 |   |   |   |
#    --- --- ---
# Player 2 (O), enter your move.
# Error: COLLISION. SPACE OCCUPIED. TRY AGAIN.
# Error: BAD MOVE. TRY AGAIN.
#     A   B   C
#    --- --- ---
# 1 | X |   |   |
#    --- --- ---
# 2 |   | O |   |
#    --- --- ---
# 3 |   |   |   |
#    --- --- ---

# %% [markdown]
# *Exercise 9:* Use all of the previous exercises to implement a full tic-tac-toe game, where an appropriate board is drawn, 2 players are repeatedly asked for a location coordinates of where they wish to place a mark, and the game status is checked until a player wins or a draw occurs.

# %%
# lets try making our game loop to see if our funcs pair well
player_x = 1
player_o = 2
empty = 0

player_x_piece = "X" 
player_o_piece = "O"
empty_space = " " 

character = {player_x: player_x_piece, 
             player_o: player_o_piece,
             empty: empty_space}

def board_initializer_compact(size):
    board = list()
    for i in range(size):
        board.append([empty]*size) #this approach loops through our created list of size and appends a list multiplied by size to our empty board list

    return board

def draw_board(board, size):
    columns = [chr(ord('A') + i) for i in range(size)]
    print("    " + "   ".join(columns)) # modded for col visual
    print('  ' + ' ---' * size)
    for i in range(size):
        row = ' | '.join([character[cell] for cell in board[i]])
        print(f'{i + 1} | {row} |') # modded for row visual
        if i < (size - 1): 
            print('  ' + ' ---' * size)
    print('  ' + ' ---' * size)

def input_convert(input, size):
    if len(input) != 2 or len(input) > 3: # user should only be able to enter str thats 2 chars long
        return None
    # make sure all input is excepted
    column = input[0].upper()
    row = input[1:]
# error handling
    if not column.isalpha() or ord(column) < ord('A') or ord(column) >= ord('A') + size:
        return None
    
    if not row.isdigit():
        return None
    
    row = int(row)
    if row < 1 or row > size:
        return None
    
    y = ord(column) - ord('A')
    x = row - 1

    return x, y

def place_player(board, player, input, size):
    coords = input_convert(input, size)
    if coords is None:
        print("PLEASE USE CORRECT FORMAT, EX: A1 OR C2")
        return False
    
    x, y = coords
    
    if 0 <= x < size and 0 <= y < size and board[x][y] == empty:
        board[x][y] = player
        return True
    else:
        if not (0 <= x < size and 0 <= y < size):
            print("Error: OUT OF BOUNDS. TRY AGAIN.")
        elif board[x][y] != empty:
            print("Error: COLLISION. SPACE OCCUPIED. TRY AGAIN.")
        return False
    
def player_move(board, player, size):
    # inform user of turn
    print(f"Player {player} ({character[player]}), enter your move.")
    while True:
        move = input(f"Player {player} ({character[player]}), enter your move.")

        if place_player(board, player, move, size):
            break
        else:
            print("Error: BAD MOVE. TRY AGAIN.")

def check_winner(board, size):
    n = len(board)  # Get the size of the board
    is_draw = True  # Assume the game is a draw unless we find empty cells

    # Check rows and columns for a win
    for i in range(n):
        # Check row i
        if board[i][0] != 0 and all(board[i][j] == board[i][0] for j in range(n)):
            return board[i][0]
        # Check column i
        if board[0][i] != 0 and all(board[j][i] == board[0][i] for j in range(n)):
            return board[0][i]

    # Check main diagonal
    if board[0][0] != 0 and all(board[i][i] == board[0][0] for i in range(n)):
        return board[0][0]

    # Check anti-diagonal
    if board[0][n-1] != 0 and all(board[i][n-i-1] == board[0][n-1] for i in range(n)):
        return board[0][n-1]

    # Check if there are any empty cells (game incomplete)
    for row in board:
        if 0 in row:
            is_draw = False  # If there's an empty space, game isn't a draw

    # If no winner and no empty cells, it's a draw
    if is_draw:
        return 0
    else:
        return -1  # Game is incomplete

def game_loop():
    while True:
        try:
            print("PLEASE ENTER BOARD SIZE. (EX: 3 FOR 3X3)")
            size = int(input())
            if size < 3:
                print("PLEASE MAKE SURE GAME SIZE IS AT LEAST 3")
            else:
                break
        except ValueError:
            print("INVALID. PLEASE ENTER A NUMBER.")

    board = board_initializer_compact(size)
    draw_board(board, size)

    current_player = player_x
    # main loop
    while True:
        player_move(board, current_player, size)
        draw_board(board, size)
        winner = check_winner(board, size)

        if winner == player_x:
            print("PLAYER X IS THE WINNER!!")
            break
        elif winner == player_o:
            print("PLAYER O IS THE WINNER!!")
            break
        elif winner == 0:
            print("DRAW!!")
            break

        current_player = player_o if current_player == player_x else player_x

# %%
game_loop()
# Out:
# PLEASE ENTER BOARD SIZE. (EX: 3 FOR 3X3)
#     A   B   C
#    --- --- ---
# 1 |   |   |   |
#    --- --- ---
# 2 |   |   |   |
#    --- --- ---
# 3 |   |   |   |
#    --- --- ---
# Player 1 (X), enter your move.
#     A   B   C
#    --- --- ---
# 1 | X |   |   |
#    --- --- ---
# 2 |   |   |   |
#    --- --- ---
# 3 |   |   |   |
#    --- --- ---
# Player 2 (O), enter your move.
#     A   B   C
#    --- --- ---
# 1 | X |   |   |
#    --- --- ---
# 2 |   | O |   |
#    --- --- ---
# 3 |   |   |   |
#    --- --- ---
# Player 1 (X), enter your move.
#     A   B   C
#    --- --- ---
# 1 | X |   |   |
#    --- --- ---
# 2 | X | O |   |
#    --- --- ---
# 3 |   |   |   |
#    --- --- ---
# Player 2 (O), enter your move.
#     A   B   C
#    --- --- ---
# 1 | X |   |   |
#    --- --- ---
# 2 | X | O |   |
#    --- --- ---
# 3 |   | O |   |
#    --- --- ---
# Player 1 (X), enter your move.
#     A   B   C
#    --- --- ---
# 1 | X |   |   |
#    --- --- ---
# 2 | X | O |   |
# ...

# %% [markdown]
# *Exercise 10:* Test that your game works for 5x5 Tic Tac Toe.

# %%
# lets mod our code so it asks for a size input at the start
# def game_loop():
#     while True:
#         try:
#             print("PLEASE ENTER BOARD SIZE. (EX: 3 FOR 3X3)")
#             size = int(input())
#         except ValueError:
#             print("INVALID. PLEASE ENTER A NUMBER.")

# def draw_board(board, size):
#     columns = [chr(ord('A') + i) for i in range(size)]

# def input_convert(input, size):
#     if len(input) != 2: # user should only be able to enter str thats 2 chars long
#         return None
#     # make sure all input is excepted
#     column = input[0].upper()
#     row = input[1]
# # error handling
#     if not column.isalpha() or not row. isdigit() or int(row) < 1 or int(row) > size:
#         return None
    
#     x = int(row) - 1 # consider index
#     y = ord(column) - ord('A')

#     if y >= size:
#         return None

#     return x, y

game_loop()


# Unable to place move past C col and 3rd row, check place_player()
# Out:
# PLEASE ENTER BOARD SIZE. (EX: 3 FOR 3X3)
#     A   B   C   D   E
#    --- --- --- --- ---
# 1 |   |   |   |   |   |
#    --- --- --- --- ---
# 2 |   |   |   |   |   |
#    --- --- --- --- ---
# 3 |   |   |   |   |   |
#    --- --- --- --- ---
# 4 |   |   |   |   |   |
#    --- --- --- --- ---
# 5 |   |   |   |   |   |
#    --- --- --- --- ---
# Player 1 (X), enter your move.
#     A   B   C   D   E
#    --- --- --- --- ---
# 1 |   |   |   |   |   |
#    --- --- --- --- ---
# 2 |   |   |   |   |   |
#    --- --- --- --- ---
# 3 |   |   |   |   |   |
#    --- --- --- --- ---
# 4 |   |   |   | X |   |
#    --- --- --- --- ---
# 5 |   |   |   |   |   |
#    --- --- --- --- ---
# Player 2 (O), enter your move.
#     A   B   C   D   E
#    --- --- --- --- ---
# 1 |   |   |   |   |   |
#    --- --- --- --- ---
# 2 |   |   |   |   |   |
#    --- --- --- --- ---
# 3 |   |   | O |   |   |
#    --- --- --- --- ---
# 4 |   |   |   | X |   |
#    --- --- --- --- ---
# 5 |   |   |   |   |   |
# ...

# %% [markdown]
# *Exercise 11:* (Advanced / Challenge) Develop a version of the game where one player is the computer. Note that you don't need to do an extensive seach for the best move. You can have the computer simply protect against loosing and otherwise try to win with straight or diagonal patterns.

# %%
# Lets develop our cp
def comp_move(board, size):
    for x in range(size):
        for y in range(size):
            if board[x][y] == empty:
                board[x][y] = player_o
                if check_winner(board, size) == player_o:
                    return
                board[x][y] = empty

    for x in range(size):
        for y in range(size):
            if board[x][y] == empty:
                board[x][y] = player_x
                if check_winner(board, size) == player_x:
                    board[x][y] = player_o
                    return
                board[x][y] = empty
    
    empty_spots = [(x,y) for x in range(size) for y in range(size) if board[x][y] == empty]
    if empty_spots:
        x, y = random.choice(empty_spots)
        board[x][y] = player_o

# %%
# Test your solution here
# lets edit our game_loop() so that the user has a choice between player and computer.

import random
player_x = 1
player_o = 2
empty = 0

player_x_piece = "X" 
player_o_piece = "O"
empty_space = " " 

character = {player_x: player_x_piece, 
             player_o: player_o_piece,
             empty: empty_space}

def board_initializer_compact(size):
    board = list()
    for i in range(size):
        board.append([empty]*size) #this approach loops through our created list of size and appends a list multiplied by size to our empty board list

    return board

def draw_board(board, size):
    columns = [chr(ord('A') + i) for i in range(size)]
    print("    " + "   ".join(columns)) # modded for col visual
    print('  ' + ' ---' * size)
    for i in range(size):
        row = ' | '.join([character[cell] for cell in board[i]])
        print(f'{i + 1} | {row} |') # modded for row visual
        if i < (size - 1): 
            print('  ' + ' ---' * size)
    print('  ' + ' ---' * size)

def input_convert(input, size):
    if len(input) != 2 or len(input) > 3: # user should only be able to enter str thats 2 chars long
        return None
    # make sure all input is excepted
    column = input[0].upper()
    row = input[1:]
# error handling
    if not column.isalpha() or ord(column) < ord('A') or ord(column) >= ord('A') + size:
        return None
    
    if not row.isdigit():
        return None
    
    row = int(row)
    if row < 1 or row > size:
        return None
    
    y = ord(column) - ord('A')
    x = row - 1

    return x, y

def place_player(board, player, input, size):
    coords = input_convert(input, size)
    if coords is None:
        print("PLEASE USE CORRECT FORMAT, EX: A1 OR C2")
        return False
    
    x, y = coords
    
    if 0 <= x < size and 0 <= y < size and board[x][y] == empty:
        board[x][y] = player
        return True
    else:
        if not (0 <= x < size and 0 <= y < size):
            print("Error: OUT OF BOUNDS. TRY AGAIN.")
        elif board[x][y] != empty:
            print("Error: COLLISION. SPACE OCCUPIED. TRY AGAIN.")
        return False
    
def player_move(board, player, size):
    # inform user of turn
    print(f"Player {player} ({character[player]}), enter your move.")
    while True:
        move = input(f"Player {player} ({character[player]}), enter your move.")

        if place_player(board, player, move, size):
            break
        else:
            print("Error: BAD MOVE. TRY AGAIN.")

def comp_move(board, size):
    for x in range(size):
        for y in range(size):
            if board[x][y] == empty:
                board[x][y] = player_o
                if check_winner(board, size) == player_o:
                    return
                board[x][y] = empty

    for x in range(size):
        for y in range(size):
            if board[x][y] == empty:
                board[x][y] = player_x
                if check_winner(board, size) == player_x:
                    board[x][y] = player_o
                    return
                board[x][y] = empty
    
    empty_spots = [(x,y) for x in range(size) for y in range(size) if board[x][y] == empty]
    if empty_spots:
        x, y = random.choice(empty_spots)
        board[x][y] = player_o

def check_winner(board, size):
    n = len(board)  # Get the size of the board
    is_draw = True  # Assume the game is a draw unless we find empty cells

    # Check rows and columns for a win
    for i in range(n):
        # Check row i
        if board[i][0] != 0 and all(board[i][j] == board[i][0] for j in range(n)):
            return board[i][0]
        # Check column i
        if board[0][i] != 0 and all(board[j][i] == board[0][i] for j in range(n)):
            return board[0][i]

    # Check main diagonal
    if board[0][0] != 0 and all(board[i][i] == board[0][0] for i in range(n)):
        return board[0][0]

    # Check anti-diagonal
    if board[0][n-1] != 0 and all(board[i][n-i-1] == board[0][n-1] for i in range(n)):
        return board[0][n-1]

    # Check if there are any empty cells (game incomplete)
    for row in board:
        if 0 in row:
            is_draw = False  # If there's an empty space, game isn't a draw

    # If no winner and no empty cells, it's a draw
    if is_draw:
        return 0
    else:
        return -1  # Game is incomplete

def game_loop():
    while True:
        try:
            print("PLEASE ENTER BOARD SIZE. (EX: 3 FOR 3X3)")
            size = int(input())
            if size < 3:
                print("PLEASE MAKE SURE GAME SIZE IS AT LEAST 3")
            else:
                break
        except ValueError:
            print("INVALID. PLEASE ENTER A NUMBER.")

    while True:
        print("PLEASE CHOOSE FOE. 'P' FOR PLAYER OR 'C' FOR COMPUTER.")
        game_mode = input().strip().upper()
        if game_mode in ['C', 'P']:
            break
        else:
            print("INVALID. PLEASE CHOOSE PLAYER OR COMPUTER.")

    board = board_initializer_compact(size)
    draw_board(board, size)

    current_player = player_x
    # main loop
    while True:
        if current_player == player_x:
            player_move(board, current_player, size)
        else:
            if game_mode == 'C':
                comp_move(board, size)
            else:
                player_move(board, current_player, size)

        draw_board(board, size)
        winner = check_winner(board, size)

        if winner == player_x:
            print("PLAYER X IS THE WINNER!!")
            break
        elif winner == player_o:
            if game_mode == 'C':
                print("COMPUTER WINS!!")
            else:
                print("PLAYER O IS THE WINNER!!")
            break
        elif winner == 0:
            print("DRAW!!")
            break

        current_player = player_o if current_player == player_x else player_x

# %%
game_loop()
# Out:
# PLEASE ENTER BOARD SIZE. (EX: 3 FOR 3X3)
# PLEASE CHOOSE FOE. 'P' FOR PLAYER OR 'C' FOR COMPUTER.
#     A   B   C
#    --- --- ---
# 1 |   |   |   |
#    --- --- ---
# 2 |   |   |   |
#    --- --- ---
# 3 |   |   |   |
#    --- --- ---
# Player 1 (X), enter your move.
#     A   B   C
#    --- --- ---
# 1 |   |   |   |
#    --- --- ---
# 2 |   | X |   |
#    --- --- ---
# 3 |   |   |   |
#    --- --- ---
#     A   B   C
#    --- --- ---
# 1 |   |   |   |
#    --- --- ---
# 2 |   | X |   |
#    --- --- ---
# 3 |   |   | O |
#    --- --- ---
# Player 1 (X), enter your move.
#     A   B   C
#    --- --- ---
# 1 |   |   | X |
#    --- --- ---
# 2 |   | X |   |
#    --- --- ---
# 3 |   |   | O |
#    --- --- ---
#     A   B   C
#    --- --- ---
# 1 |   |   | X |
#    --- --- ---
# 2 |   | X |   |
#    --- --- ---
# 3 | O |   | O |
#    --- --- ---
# Player 1 (X), enter your move.
# Error: COLLISION. SPACE OCCUPIED. TRY AGAIN.
# Error: BAD MOVE. TRY AGAIN.
#     A   B   C
#    --- --- ---
# ...
